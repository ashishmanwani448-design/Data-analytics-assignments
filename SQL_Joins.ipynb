# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishmanwani448-design/Data-analytics-assignments/blob/main/SQL_Joins.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## SQL joins
#
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Question 1. Retrieve all customers who have placed at least one order
#
# Ans:
#
#
# ***Query***:
#
#     " SELECT cu.Customer_name
#     FROM Customers AS cu
#     JOIN Orders AS o
#     ON cu.Customer_id = o.CustomerID
#     WHERE o.Amount <> 0; "
#
#
# ***Result***:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Question 2. Retrieve all customers and their orders, including customers who have not placed any orders.
#
# Ans:
#
# ***query***:
#
#     SELECT *
#     FROM Customers AS cu
#     left JOIN Orders AS o
#     ON cu.Customer_id = o.CustomerID;
#
# **Result:**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Question 3. Retrieve all orders and their corresponding customers, including orders placed by unknown
# customers.
#
# Ans:
#
# **Query**:
#
#     SELECT *
#     FROM Customers AS cu
#     Right outer JOIN Orders AS o
#     ON cu.Customer_id = o.CustomerID;
#
#
# **Result:**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Question 4. Display all customers and orders, whether matched or not.
#
# Ans:
#
#
# ***query***:
#
#     SELECT * FROM Customers AS cu
#     LEFT JOIN Orders AS o
#     ON cu.Customer_id= o.CustomerID
#
#     UNION
#
#     SELECT *
#     FROM Customers AS cu
#     RIGHT JOIN Orders AS o
#     ON cu.Customer_id = o.CustomerID;
#
#
# ***Result***:
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Question 5. Find customers who have not placed any orders.
#
# Ans:
#
# ***Query***:
#
#     " SELECT cu.Customer_name
#     FROM Customers AS cu
#     LEFT JOIN Orders AS o
#     ON cu.Customer_id = o.CustomerID
#     WHERE o.OrderID IS NULL;"
#
# ***Result***:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Question 6. Retrieve customers who made payments but did not place any orders.
#
# Ans:
#
#
# ***Query:***
#
#     "SELECT *
#     FROM Customers AS cu
#     Left JOIN orders AS o
#     ON cu.Customer_id = o.CustomerID
#     left outer join payments as p
#     on cu.Customer_id = p.CustomerID
#     where p.amount <> 0 and o.OrderID is Null"
#
#
# ***Result:***
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Question 7. Generate a list of all possible combinations between Customers and Orders.
#
# Ans:
#
# ***Query***:
#
#     "SELECT *
#     FROM customers c
#     CROSS JOIN orders o;"
#
#
# ****Result****:
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Question 8. Show all customers along with order and payment amounts in one table.
#
# Ans:
#
# ***Query***:
#
#     "SELECT *
#     FROM Customers AS cu
#     left  JOIN orders AS o
#     ON cu.Customer_id = o.CustomerID
#
#     union
#
#     SELECT *
#     FROM Customers AS cu
#     right  JOIN orders AS o
#     ON cu.Customer_id = o.CustomerID;"
#
#
# ***Result***:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Question 9. Retrieve all customers who have both placed orders and made payments.
#
# Ans:
#
#
# ***Query***:
#
#     "SELECT cu.Customer_name
#     right  JOIN orders AS o
#     ON cu.Customer_id = o.CustomerID
#     right join payments as p
#     on p.CustomerID= o.CustomerID
#     where o.amount<>0 and p.amount <> 0;"
#
# ***Result***:
#
# ![image.png](data:image/png;base64,...)
